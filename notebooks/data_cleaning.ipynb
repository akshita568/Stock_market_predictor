# %%
import os
import sys
if os.getcwd().endswith("notebooks"):
    os.chdir("..")

sys.path.append(os.getcwd())

# %%
from src.components.data_ingestion import DataIngestion

ingestion = DataIngestion()
df = ingestion.initiate_data_ingestion()

df.head()
# Out:
# [*********************100%***********************]  503 of 503 completed
#         date symbol   adj close       close        high         low  \
# 0 2024-01-02      A  136.120499  138.750000  140.589996  137.910004
# 1 2024-01-02   AAPL  183.562195  185.639999  188.440002  183.889999
# 2 2024-01-02   ABBV  146.569778  159.820007  160.139999  154.770004
# 3 2024-01-02   ABNB  134.479996  134.479996  135.600006  133.339996
# 4 2024-01-02    ABT  104.509552  109.849998  111.000000  109.559998
#
#          open      volume
# 0  138.190002   1441600.0
# 1  187.149994  82488700.0
# 2  154.899994   8059900.0
# 3  134.429993   3485200.0
# 4  109.559998   5058600.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 315381 entries, 0 to 315380
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   date       315381 non-null  datetime64[s]
#  1   symbol     315381 non-null  str
#  2   adj close  313312 non-null  float64
#  3   close      313312 non-null  float64
#  4   high       313312 non-null  float64
#  5   low        313312 non-null  float64
#  6   open       313312 non-null  float64
#  7   volume     313312 non-null  float64
# dtypes: datetime64[s](1), float64(6), str(1)
# memory usage: 19.2 MB

# %%
df.describe()
# Out:
#                       date      adj close          close           high  \
# count               315381  313312.000000  313312.000000  313312.000000
# mean   2025-04-01 16:25:15     203.330946     206.331247     208.857028
# min    2024-01-02 00:00:00       6.710000       6.710000       6.980000
# 25%    2024-08-15 00:00:00      67.748653      69.550003      70.430000
# 50%    2025-04-02 00:00:00     122.839996     125.783501     127.339996
# 75%    2025-11-14 00:00:00     225.917347     229.449997     232.179993
# max    2026-07-02 00:00:00    9924.400391    9924.400391    9964.769531
# std                    NaN     414.402658     415.086094     420.059886
#
#                  low           open        volume
# count  313312.000000  313312.000000  3.133120e+05
# mean      203.729998     206.322862  6.434690e+06
# min         6.640000       6.670000  0.000000e+00
# 25%        68.660004      69.540001  1.195300e+06
# 50%       124.190002     125.820000  2.514600e+06
# ...

# %%
df.shape
# Out:
# (315381, 8)

# %%
df.columns
# Out:
# Index(['date', 'symbol', 'adj close', 'close', 'high', 'low', 'open',
#        'volume'],
#       dtype='str')

# %%
df.duplicated(subset=['symbol', 'date']).sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# date            0
# symbol          0
# adj close    2069
# close        2069
# high         2069
# low          2069
# open         2069
# volume       2069
# dtype: int64

# %%
df[df['close'].isna()].sample(10)
# Out:
#              date symbol  adj close  close  high  low  open  volume
# 206458 2025-08-21   HONA        NaN    NaN   NaN  NaN   NaN     NaN
# 94445  2024-09-30      Q        NaN    NaN   NaN  NaN   NaN     NaN
# 60085  2024-06-24   HONA        NaN    NaN   NaN  NaN   NaN     NaN
# 91451  2024-09-20   SNDK        NaN    NaN   NaN  NaN   NaN     NaN
# 151787 2025-03-17      Q        NaN    NaN   NaN  NaN   NaN     NaN
# 44169  2024-05-07   SNDK        NaN    NaN   NaN  NaN   NaN     NaN
# 408    2024-01-02   SNDK        NaN    NaN   NaN  NaN   NaN     NaN
# 126637 2024-12-31      Q        NaN    NaN   NaN  NaN   NaN     NaN
# 107044 2024-11-04   SNDK        NaN    NaN   NaN  NaN   NaN     NaN
# 162350 2025-04-15      Q        NaN    NaN   NaN  NaN   NaN     NaN

# %% [markdown]
# VICI, VLTO, CARR, CPAY, SNDK Many of these weren't publicly traded during some of the dates in the dataset.
# this means companies that didn't exist or weren't listed during the earlier years, the data source returns NaN for those dates.

# %%
#check how much data is missing for each company
missing_counts = (
    df.groupby('symbol')['close']
      .apply(lambda x: x.isna().sum())
      .sort_values(ascending=False)
)

print(missing_counts.head(20))
# Out:
# symbol
# HONA    614
# FDXF    601
# Q       456
# SNDK    280
# GEV      59
# SOLV     58
# FISV      1
# AIG       0
# AIZ       0
# AJG       0
# AKAM      0
# ALB       0
# ALGN      0
# ALL       0
# TSLA      0
# BAX       0
# WAB       0
# VRSK      0
# AMT       0
# ZTS       0
# Name: close, dtype: int64
