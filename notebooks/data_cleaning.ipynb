# %%
import os
import sys
if os.getcwd().endswith("notebooks"):
    os.chdir("..")

sys.path.append(os.getcwd())

# %%
from src.components.data_ingestion import DataIngestion

ingestion = DataIngestion()
df = ingestion.initiate_data_ingestion()

df.head()
# Out:
# [*********************100%***********************]  503 of 503 completed
#         date symbol  adj close      close       high        low       open  \
# 0 2015-01-02      A        NaN        NaN        NaN        NaN        NaN
# 1 2015-01-02   AAPL  24.192606  27.332500  27.860001  26.837500  27.847500
# 2 2015-01-02   ABBV  41.411907  65.889999  66.400002  65.440002  65.440002
# 3 2015-01-02   ABNB        NaN        NaN        NaN        NaN        NaN
# 4 2015-01-02    ABT  36.009205  44.900002  45.450001  44.639999  45.250000
#
#         volume
# 0          NaN
# 1  212818400.0
# 2    5086100.0
# 3          NaN
# 4    3216600.0
